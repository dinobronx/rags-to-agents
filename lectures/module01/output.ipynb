# %%
from openai import OpenAI
from pydantic import BaseModel

# %%
client = OpenAI()

class CalendarEvent(BaseModel):
    name: str
    date: str
    participants: list[str]

# %%
response = client.responses.parse(
    model='gpt-4o-mini',
    input=[
        {"role": "system", "content": "Extract the event information."},
        {"role": "user",
         "content": "Alice and Bob are going to a science fair on Friday.",
        },
    ],
    text_format=CalendarEvent,
)

# %%
response
# Out:
# ParsedResponse[TypeVar](id='resp_075966acfc4f29290069f5a58ea5588193a04498f67a49357c', created_at=1777706382.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-4o-mini-2024-07-18', object='response', output=[ParsedResponseOutputMessage[TypeVar](id='msg_075966acfc4f29290069f5a58f5f708193be09becf42c324e1', content=[ParsedResponseOutputText[TypeVar](annotations=[], text='{"name":"Science Fair","date":"Friday","participants":["Alice","Bob"]}', type='output_text', logprobs=[], parsed=CalendarEvent(name='Science Fair', date='Friday', participants=['Alice', 'Bob']))], role='assistant', status='completed', type='message', phase=None)], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[], top_p=1.0, background=False, completed_at=1777706383.0, conversation=None, max_output_tokens=None, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, prompt_cache_retention='in_memory', reasoning=Reasoning(effort=None, genera
# ...

# %%
response.output[0].content[0].parsed
# Out:
# CalendarEvent(name='Science Fair', date='Friday', participants=['Alice', 'Bob'])

# %%
response.output[0].content[0].text
# Out:
# '{"name":"Science Fair","date":"Friday","participants":["Alice","Bob"]}'

# %%
event = response.output_parsed

# %%
event
# Out:
# CalendarEvent(name='Science Fair', date='Friday', participants=['Alice', 'Bob'])

# %%
# removing text_format, and using create method

response = client.responses.create(
    model='gpt-4o-mini',
    input=[
        {"role": "system", "content": "Extract the event information."},
        {"role": "user",
         "content": "Alice and Bob are going to a science fair on Friday.",
        },
    ],
)

print(response.output_text)
# Out:
# - **Event**: Science Fair
# - **Participants**: Alice and Bob
# - **Day**: Friday

# %% [markdown]
# Observe that output could be different because we did not identify a schema.
#
# -- Output 1
# Event: Science Fair
# Participants: Alice and Bob
# Date: Friday
#
# -- Output 2
# - **Event**: Science Fair
# - **Participants**: Alice and Bob
# - **Day**: Friday
